# %% [markdown]
# #Kavish Nag
# #24070126085
# #AIML B1

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn import neighbors
from sklearn.metrics import mean_squared_error
from math import sqrt

# %%
df = pd.read_csv("/content/Book1.csv")
df
# Out:
#    Petal Width  Sepal Length  Petal Length  Sepal Width
# 0          0.2           5.1           1.4          3.5
# 1          1.5           6.0           4.5          2.9
# 2          1.8           6.5           5.5          3.0
# 3          1.3           5.9           4.2          3.2

# %%
x = df.drop('Petal Length', axis=1)
y = df['Petal Length']

# %%
model = neighbors.KNeighborsRegressor(n_neighbors=3)
model.fit(x,y)
pred = model.predict(x)
error = sqrt(mean_squared_error(y,pred))
error
# Out:
# 1.0948109933276662

# %%
sepal_length_mean = x['Sepal Length'].mean()
sepal_width_mean = x['Sepal Width'].mean()
pred = model.predict([[1.4, sepal_length_mean, sepal_width_mean]])
pred
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but KNeighborsRegressor was fitted with feature names
#   warnings.warn(
# array([4.73333333])
