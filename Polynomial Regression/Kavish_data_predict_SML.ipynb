# %% [markdown]
# #Kavish Nag
# #24070126085
# #AIML B1

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression

# %%
df = pd.read_csv("/content/data .csv")
df
# Out:
#    Sno  Temperature  Pressure
# 0    1            0    0.0002
# 1    2           20    0.0012
# 2    3           40    0.0060
# 3    4           60    0.0300
# 4    5           80    0.0900
# 5    6          100    0.2700

# %%
df.shape
# Out:
# (6, 3)

# %%
X=df.iloc[:,1].values.reshape(-1,1)
y=df.iloc[:,2].values
print(X)
print(y)
# Out:
# [[  0]
#  [ 20]
#  [ 40]
#  [ 60]
#  [ 80]
#  [100]]
# [2.0e-04 1.2e-03 6.0e-03 3.0e-02 9.0e-02 2.7e-01]

# %%
plt.scatter(X,y,color="k")
plt.title("Original Data")
plt.xlabel("Temp")
plt.ylabel("Pressure")
# Out:
# Text(0, 0.5, 'Pressure')

# %%
LR = LinearRegression()
LR.fit(X,y)
# Out:
# LinearRegression()

# %%
y_pred = LR.predict(X)
df=pd.DataFrame({'Actual':y ,'Predicted':y_pred})
print(df)
# Out:
#    Actual  Predicted
# 0  0.0002  -0.050867
# 1  0.0012  -0.004027
# 2  0.0060   0.042813
# 3  0.0300   0.089653
# 4  0.0900   0.136493
# 5  0.2700   0.183333

# %%
from sklearn.metrics import r2_score
r2_score(y,y_pred)
# Out:
# 0.690349972603981

# %%
plt.scatter(X,y,color="k")
plt.plot(X,y_pred,color="red")
plt.xlabel("Temp (C)")
plt.ylabel("Pressure")
plt.title('Polynomial Regression')
plt.legend()
plt.show()
# Out:
# /tmp/ipython-input-4038859657.py:6: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
poly = PolynomialFeatures(degree=3)
X_poly = poly.fit_transform(X)

# %%
model = LinearRegression()
model.fit(X_poly,y)
# Out:
# LinearRegression()

# %%
y_pred=model.predict(X_poly)

df=pd.DataFrame({'Actual':y ,'Predicted':y_pred})
print(df)
# Out:
#    Actual  Predicted
# 0  0.0002  -0.001989
# 1  0.0012   0.007244
# 2  0.0060   0.003711
# 3  0.0300   0.022489
# 4  0.0900   0.098656
# 5  0.2700   0.267289

# %%
y_pred = model.predict(X_poly)
r2_score(y,y_pred)
# Out:
# 0.9966691251761722

# %%
plt.scatter(X,y,color="k")
plt.plot(X,y_pred,color="red")
plt.xlabel("Temp (C)")
plt.ylabel("Pressure")
plt.title('Polynomial Regression')
plt.legend()
plt.show()
# Out:
# /tmp/ipython-input-4038859657.py:6: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
