# %% [markdown]
# #Kavish Nag
# #24070126085
# #AIML B1

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression

# %%
np.random.seed(0)
x = 2-3*np.random.normal(0,1,20)
y = x - 2*(x**2)+0.5*(x**3) + np.random.normal(-3,3,20)
plt.scatter(x,y,s=10)
plt.show()

# %% [markdown]
# LINEAR REGRESSION

# %%
LR = LinearRegression()
x = x.reshape(-1,1)
LR.fit(x.reshape(-1,1),y)
# Out:
# LinearRegression()

# %%
y_pred = LR.predict(x)
df=pd.DataFrame({'Actual':y ,'Predicted':y_pred})
print(df)
# Out:
#         Actual  Predicted
# 0   -53.468412 -44.096293
# 1    -1.262560 -10.166452
# 2    -3.506193 -24.559900
# 3  -107.223200 -55.958740
# 4   -49.131950 -46.671219
# 5     8.901224  24.100225
# 6    -5.466242 -23.847180
# 7    -5.762632   3.553662
# 8    -0.600586   2.356117
# 9     1.222678 -10.426201
# 10   -3.956637  -3.795071
# 11  -21.989895 -36.389874
# 12   -6.118123 -19.144135
# 13  -10.468440  -3.238605
# 14   -4.119557 -11.253733
# 15   -3.029419  -8.512546
# 16  -21.761523 -37.380124
# 17   -1.512952   4.892080
# 18   -4.754912  -7.999912
# 19    6.507233  21.035803

# %%
from sklearn.metrics import r2_score
r2_score(y,y_pred)
# Out:
# 0.6386750054827146

# %%
plt.scatter(x,y,color="k")
plt.plot(x,y_pred,color="red")
plt.xlabel("Temp (C)")
plt.ylabel("Pressure")
plt.title('Polynomial Regression')
plt.legend()
plt.show()
# Out:
# /tmp/ipython-input-748344636.py:6: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %% [markdown]
# #Polynomial Regression

# %%
poly = PolynomialFeatures(degree=3)
X_poly = poly.fit_transform(x.reshape(-1,1))
model = LinearRegression()
model.fit(X_poly,y)
# Out:
# LinearRegression()

# %%
y_pred=model.predict(X_poly)

df=pd.DataFrame({'Actual':y ,'Predicted':y_pred})
print(df)
# Out:
#         Actual   Predicted
# 0   -53.468412  -45.796189
# 1    -1.262560   -2.431296
# 2    -3.506193   -5.308172
# 3  -107.223200 -105.694496
# 4   -49.131950  -56.073123
# 5     8.901224   10.783717
# 6    -5.466242   -4.798428
# 7    -5.762632   -5.073713
# 8    -0.600586   -4.982974
# 9     1.222678   -2.387555
# 10   -3.956637   -3.845989
# 11  -21.989895  -22.725094
# 12   -6.118123   -2.592062
# 13  -10.468440   -3.976757
# 14   -4.119557   -2.261287
# 15   -3.029419   -2.748331
# 16  -21.761523  -25.097930
# 17   -1.512952   -5.099237
# 18   -4.754912   -2.857783
# 19    6.507233    5.464603

# %%
from sklearn.metrics import r2_score
r2_score(y,y_pred)
# Out:
# 0.9830071790386679

# %%
x_range = np.linspace(x.min(), x.max(), 100).reshape(-1, 1)
x_range_poly = poly.transform(x_range)
y_range_pred = model.predict(x_range_poly)

plt.scatter(x, y, color='blue', label='Actual data')
plt.plot(x_range, y_range_pred, color='red', label='Polynomial degree 3')
plt.title('Polynomial Regression')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.show()
